# %%
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
from yahoofinancials import YahooFinancials

# Correct the file path and quote characters
ticker_details = pd.read_excel(r'Data\Ticker_List.xlsx')

# Retrieve tickers and names
ticker = ticker_details['Ticker'].to_list()
names = ticker_details['Description'].to_list()

# Display the first 20 rows
ticker_details.head(20)
# Out:
#       Ticker              Description
# 0       GC=F                     Gold
# 1       SI=F                   Silver
# 2       CL=F                Crude Oil
# 3      ^GSPC                   S&P500
# 4       ^RUT        Russel 2000 Index
# 5       ZN=F  10 Yr US T-Note futures
# 6       ZT=F   2 Yr US T-Note Futures
# 7       PL=F                 Platinum
# 8       HG=F                   Copper
# 9       DX=F             Dollar Index
# 10      ^VIX         Volatility Index
# 11       S=F                  Soybean
# 12       EEM              MSCI EM ETF
# 13  EURUSD=X                 Euro USD
# 14     ^N100              Euronext100
# 15     ^IXIC                   Nasdaq

# %%
# Creating Date Range and adding them to values table
end_date = "2020-03-01"
start_date = "2010-01-01"
date_range = pd.bdate_range(start=start_date, end=end_date)
values = pd.DataFrame({'Date': date_range})
values['Date'] = pd.to_datetime(values['Date'])

# %%
# Define the date range
end_date = "2020-03-01"
start_date = "2010-01-01"
date_range = pd.bdate_range(start=start_date, end=end_date)

# Create the values DataFrame with dates
values = pd.DataFrame({'Date': date_range})
values['Date'] = pd.to_datetime(values['Date'])

# List of ticker codes
# Make sure `ticker` and `names` are defined lists of tickers and descriptions respectively

for i in ticker:
    raw_data = YahooFinancials(i)
    data = raw_data.get_historical_price_data(start_date, end_date, "daily")
    
    # Check if there is data available for the ticker
    if i in data:
        df = pd.DataFrame(data[i]['prices'])[['formatted_date', 'adjclose']]
        df.columns = ['Date1', i]  # Rename columns to 'Date1' and the ticker symbol
        df['Date1'] = pd.to_datetime(df['Date1'])
        
        # Merge with the values DataFrame on the Date column
        values = values.merge(df, how='left', left_on='Date', right_on='Date1')
        values = values.drop(labels='Date1', axis=1)  # Drop the auxiliary 'Date1' column

# Rename columns to more descriptive names based on 'names' list
names.insert(0, 'Date')
values.columns = names

print(values.shape)
print(values.isna().sum())

# Fill NaN values using forward and backward fill
values = values.fillna(method="ffill", axis=0)
values = values.fillna(method="bfill", axis=0)
print(values.isna().sum())

# Convert all columns except 'Date' to numeric, coercing errors to NaN, and round to 1 decimal place
cols = values.columns.drop('Date')
values[cols] = values[cols].apply(pd.to_numeric, errors='coerce').round(decimals=1)
print(values.tail())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Legion\Documents\PythonStatsProject\PythonStatsProject\.venv\Lib\site-packages\yahoofinancials\data.py:567, in YahooFinanceData._retry_create_dict_ent(self, up_ticker, statement_type, tech_type, report_name, hist_obj)
#     566 try:
# --> 567     out = self._create_dict_ent(up_ticker, statement_type, tech_type, report_name, hist_obj)
#     568     return out
#
# File c:\Users\Legion\Documents\PythonStatsProject\PythonStatsProject\.venv\Lib\site-packages\yahoofinancials\data.py:528, in YahooFinanceData._create_dict_ent(self, up_ticker, statement_type, tech_type, report_name, hist_obj)
#     527 try:
# --> 528     cleaned_re_data = self._recursive_api_request(hist_obj, up_ticker)
#     529 except KeyError:
#
# File c:\Users\Legion\Documents\PythonStatsProject\PythonStatsProject\.venv\Lib\site-packages\yahoofinancials\data.py:510, in YahooFinanceData._recursive_api_request(self, hist_obj, up_ticker, clean, i)
#     509 if clean:
# --> 510     re_data = self._clean_api_data(self._build_api_url(hist_obj, up_ticker, v))
#     511     cleaned_re_data = self._clean_historical_data(re_data)
#
# File c:\Users\Legion\Documents\PythonStatsProject\PythonStatsProject\.venv\Lib\site-packages\yahoofinancials\data.py:467, in YahooFinanceData._clean_api_data(self, api_url)
#     466 def _clean_api_data(self, api_url):
# --> 467     raw_data = self._get_api_data(api_url)
#     468     ret_obj = {}
#
# File c:\Users\Legion\Documents\PythonStatsProject\PythonStatsProject\.venv\Lib\site-packages\yahoofinancials\data.py:447, in YahooFinanceData._get_api_data(self, api_url, tries)
#     446 urlopener = UrlOpener(self.session)
# --> 447 response = urlopener.open(cur_url, proxy=self._get_proxy(), timeout=self.timeout)
#     448 if response.status_code == 200:
#
# File c:\Users\Legion\Documents\PythonStatsProject\PythonStatsProject\.venv\Lib\site-packages\yahoofinancials\data.py:43, in UrlOpener.open(self, url, request_headers, params, proxy, timeout)
#      42 def open(self, url, request_headers=None, params=None, proxy=None, timeout=30):
# ---> 43     response = self._session_manager.cache_get(
#      44         url=url,
#      45         params=params,
#      46         proxy=proxy,
#      47         timeout=timeout,
#      48         user_agent_headers=request_headers or self.request_headers
#      49     )
#      50     return response
#
# File c:\Users\Legion\Documents\PythonStatsProject\PythonStatsProject\.venv\Lib\site-packages\yahoofinancials\sessions.py:135, in lru_cache_freezeargs.<locals>.wrapped(*args, **kwargs)
#     134 kwargs = {k: tuple(v) if isinstance(v, list) else v for k, v in kwargs.items()}
# --> 135 return func(*args, **kwargs)
#
# File c:\Users\Legion\Documents\PythonStatsProject\PythonStatsProject\.venv\Lib\site-packages\yahoofinancials\sessions.py:464, in SessionManager.cache_get(self, url, user_agent_headers, params, proxy, timeout)
#     461 @lru_cache_freezeargs
#     462 @lru_cache(maxsize=cache_maxsize)
#     463 def cache_get(self, url, user_agent_headers=None, params=None, proxy=None, timeout=30):
# --> 464     return self.get(url, user_agent_headers, params, proxy, timeout)
#
# File c:\Users\Legion\Documents\PythonStatsProject\PythonStatsProject\.venv\Lib\site-packages\yahoofinancials\sessions.py:428, in SessionManager.get(self, url, user_agent_headers, params, proxy, timeout)
#     427     raise Exception("yahoofinancials: Don't manually add 'crumb' to params dict, let sessions.py handle it")
# --> 428 cookie, crumb, strategy = self._get_cookie_and_crumb()
#     429 if crumb is not None:
#
# File c:\Users\Legion\Documents\PythonStatsProject\PythonStatsProject\.venv\Lib\site-packages\yahoofinancials\sessions.py:413, in SessionManager._get_cookie_and_crumb(self, proxy, timeout)
#     411 else:
#     412     # Fallback strategy
# --> 413     cookie, crumb = self._get_cookie_and_crumb_basic(proxy, timeout)
#     414     if cookie is None or crumb is None:
#     415         # Fail
#
# File c:\Users\Legion\Documents\PythonStatsProject\PythonStatsProject\.venv\Lib\site-packages\yahoofinancials\sessions.py:316, in SessionManager._get_cookie_and_crumb_basic(self, proxy, timeout)
#     315 def _get_cookie_and_crumb_basic(self, proxy, timeout):
# --> 316     cookie = self._get_cookie_basic(proxy, timeout)
#     317     crumb = self._get_crumb_basic(proxy, timeout)
#
# File c:\Users\Legion\Documents\PythonStatsProject\PythonStatsProject\.venv\Lib\site-packages\yahoofinancials\sessions.py:263, in SessionManager._get_cookie_basic(self, proxy, timeout)
#     262     return self._cookie
# --> 263 self._cookie = self._load_cookie_basic()
#     264 if self._cookie is not None:
#
# File c:\Users\Legion\Documents\PythonStatsProject\PythonStatsProject\.venv\Lib\site-packages\yahoofinancials\sessions.py:250, in SessionManager._load_cookie_basic(self)
#     249 def _load_cookie_basic(self):
# --> 250     cookie_dict = cache.get_cookie_cache().lookup('basic')
#     251     if cookie_dict is None:
#
# File c:\Users\Legion\Documents\PythonStatsProject\PythonStatsProject\.venv\Lib\site-packages\yahoofinancials\cache.py:373, in _CookieCache.lookup(self, strategy)
#     372     cookie = _pkl.loads(data.cookie_bytes)
# --> 373     return {'cookie': cookie, 'age': _datetime.datetime.now() - data.fetch_date}
#     374 except _CookieSchema.DoesNotExist:
#
# TypeError: unsupported operand type(s) for -: 'datetime.datetime' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 15
#      13 for i in ticker:
#      14     raw_data = YahooFinancials(i)
# ---> 15     data = raw_data.get_historical_price_data(start_date, end_date, "daily")
#      17     # Check if there is data available for the ticker
#      18     if i in data:
#
# File c:\Users\Legion\Documents\PythonStatsProject\PythonStatsProject\.venv\Lib\site-packages\yahoofinancials\yf.py:163, in YahooFinancials.get_historical_price_data(self, start_date, end_date, time_interval)
#     161 end = self.format_date(end_date)
#     162 hist_obj = {'start': start, 'end': end, 'interval': interval_code}
# --> 163 return self.get_stock_data('history', hist_obj=hist_obj)
#
# File c:\Users\Legion\Documents\PythonStatsProject\PythonStatsProject\.venv\Lib\site-packages\yahoofinancials\data.py:630, in YahooFinanceData.get_stock_data(self, statement_type, tech_type, report_name, hist_obj)
#     628     report_name = 'assetProfile'
#     629 if isinstance(self.ticker, str):
# --> 630     dict_ent = self._retry_create_dict_ent(self.ticker, statement_type, tech_type, report_name, hist_obj)
#     631     data.update(dict_ent)
#     632 else:
#
# File c:\Users\Legion\Documents\PythonStatsProject\PythonStatsProject\.venv\Lib\site-packages\yahoofinancials\data.py:570, in YahooFinanceData._retry_create_dict_ent(self, up_ticker, statement_type, tech_type, report_name, hist_obj)
#     568     return out
#     569 except:
# --> 570     time.sleep(random.randint(2, 10))
#     571     i += 1
#     572     continue
#
# KeyboardInterrupt:

# %%
imp = ['Gold', 'Silver', 'Crude Oil', 'S&P500', 'MSCI EM ETF']

# Calculating Short-term Historical Returns
change_days = [1, 3, 5, 14, 21]

# Initialize a DataFrame with the 'Date' column
data = pd.DataFrame(data=values['Date'])

for i in change_days:
    print(data.shape)
    # Calculate percentage change and add suffix indicating the time period
    x = values[cols].pct_change(periods=i).add_suffix("-T-" + str(i))
    data = pd.concat([data, x], axis=1)

print(data.shape)

# Calculating Long-term Historical Returns
change_days = [60, 90, 180, 250]

for i in change_days:
    print(data.shape)
    # Calculate percentage change for the selected important columns
    x = values[imp].pct_change(periods=i).add_suffix("-T-" + str(i))
    data = pd.concat([data, x], axis=1)

print(data.shape)
